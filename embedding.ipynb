# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### sentences
sent=[ 'the glass of milk',
      'the glass of juice',
       'the cup of tea',
       'I am a good boy',
       'I am a good developer',
       'understand the meaning of words',
       'your videos are good',

]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
##Define the vocabulary size
voc_size =10000

# %%
###One Hot Representation
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[2657, 5609, 4732, 2125],
#  [2657, 5609, 4732, 9656],
#  [2657, 2327, 4732, 1267],
#  [1700, 3445, 1506, 838, 4570],
#  [1700, 3445, 1506, 838, 4597],
#  [1062, 2657, 7023, 4732, 5125],
#  [4603, 1834, 4489, 838]]

# %%
#word embedding representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length = 8
embedded_docs = pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 2657 5609 4732 2125]
#  [   0    0    0    0 2657 5609 4732 9656]
#  [   0    0    0    0 2657 2327 4732 1267]
#  [   0    0    0 1700 3445 1506  838 4570]
#  [   0    0    0 1700 3445 1506  838 4597]
#  [   0    0    0 1062 2657 7023 4732 5125]
#  [   0    0    0    0 4603 1834 4489  838]]

# %%
## feature representation
dim=10# for 10 features

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))

model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)              │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# array([[[ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.00888033,  0.03062949, -0.0448764 ,  0.01047868,
#          -0.03260628,  0.01121153,  0.00290543, -0.02765107,
#          -0.04798968,  0.03071565],
#         [ 0.01740136, -0.00744066,  0.03062725, -0.00139483,
#           0.02396477,  0.0080872 ,  0.02169557,  0.02312605,
#           0.03942302,  0.02930372],
#         [ 0.04266275, -0.01209296,  0.03286846,  0.02094408,
#           0.03892087, -0.04899366, -0.00616714,  0.03066054,
#           0.03578006, -0.03786604],
#         [ 0.04649094,  0.01658745, -0.00435399,  0.01235045,
#          -0.02393621,  0.02161782,  0.04900526, -0.02386959,
#           0.02127314,  0.02714082]],
#
#        [[ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.00888033,  0.03062949, -0.0448764 ,  0.01047868,
#          -0.03260628,  0.01121153,  0.00290543, -0.02765107,
#          -0.04798968,  0.03071565],
#         [ 0.01740136, -0.00744066,  0.03062725, -0.00139483,
#           0.02396477,  0.0080872 ,  0.02169557,  0.02312605,
#           0.03942302,  0.02930372],
#         [ 0.04266275, -0.01209296,  0.03286846,  0.02094408,
#           0.03892087, -0.04899366, -0.00616714,  0.03066054,
#           0.03578006, -0.03786604],
#         [-0.02228665,  0.03925723, -0.01955878, -0.0416513 ,
#          -0.0298506 , -0.03832176, -0.01196637, -0.02004814,
#           0.03891138,  0.01737655]],
#
#        [[ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.00888033,  0.03062949, -0.0448764 ,  0.01047868,
#          -0.03260628,  0.01121153,  0.00290543, -0.02765107,
#          -0.04798968,  0.03071565],
#         [-0.02720782,  0.04452772, -0.02536504,  0.03680066,
#           0.00063161,  0.02124843, -0.03369155,  0.02749478,
#          -0.04979124, -0.0123324 ],
#         [ 0.04266275, -0.01209296,  0.03286846,  0.02094408,
#           0.03892087, -0.04899366, -0.00616714,  0.03066054,
#           0.03578006, -0.03786604],
#         [ 0.01007079, -0.04050809, -0.01572897,  0.04717597,
#           0.04213658, -0.02262115,  0.02725365,  0.00302628,
#           0.0398748 ,  0.03281425]],
#
#        [[ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [-0.03120751, -0.00492567,  0.03936848,  0.03625742,
#           0.0226009 ,  0.03187667, -0.02015067, -0.01991847,
#          -0.01801839,  0.00648268],
#         [-0.04122671, -0.02357597,  0.00196427, -0.02649758,
#          -0.0465505 , -0.00981592,  0.0336414 , -0.04601287,
#          -0.01354749,  0.04707407],
#         [-0.00043485,  0.00929551, -0.02065741, -0.01673876,
#          -0.02751324,  0.01963257, -0.01380629, -0.04855105,
#           0.02176757,  0.02956876],
#         [-0.02199103, -0.03822392,  0.01808083, -0.04034377,
#           0.03110459,  0.0361602 ,  0.01580681,  0.03885395,
#           0.00293847,  0.04842247],
#         [ 0.02379975,  0.0117107 , -0.00374635,  0.04403217,
#          -0.02741431, -0.02970129,  0.01310733,  0.02492232,
#          -0.03431978,  0.0035492 ]],
#
#        [[ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [-0.03120751, -0.00492567,  0.03936848,  0.03625742,
#           0.0226009 ,  0.03187667, -0.02015067, -0.01991847,
#          -0.01801839,  0.00648268],
#         [-0.04122671, -0.02357597,  0.00196427, -0.02649758,
#          -0.0465505 , -0.00981592,  0.0336414 , -0.04601287,
#          -0.01354749,  0.04707407],
#         [-0.00043485,  0.00929551, -0.02065741, -0.01673876,
#          -0.02751324,  0.01963257, -0.01380629, -0.04855105,
#           0.02176757,  0.02956876],
#         [-0.02199103, -0.03822392,  0.01808083, -0.04034377,
#           0.03110459,  0.0361602 ,  0.01580681,  0.03885395,
#           0.00293847,  0.04842247],
#         [ 0.01288245, -0.00420511, -0.00659232,  0.03757656,
#           0.04193617,  0.0133526 , -0.04904469, -0.02954811,
#          -0.01825817,  0.03283444]],
#
#        [[ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [-0.0077147 , -0.04642449,  0.02821955,  0.04370684,
#           0.00738562, -0.01531376,  0.03557307,  0.02331574,
#           0.02172429,  0.01236662],
#         [ 0.00888033,  0.03062949, -0.0448764 ,  0.01047868,
#          -0.03260628,  0.01121153,  0.00290543, -0.02765107,
#          -0.04798968,  0.03071565],
#         [ 0.01610955, -0.02491897,  0.03460367,  0.0178589 ,
#           0.03338413,  0.0471759 ,  0.00603985,  0.04773891,
#           0.03759566, -0.00248826],
#         [ 0.04266275, -0.01209296,  0.03286846,  0.02094408,
#           0.03892087, -0.04899366, -0.00616714,  0.03066054,
#           0.03578006, -0.03786604],
#         [-0.02528598, -0.04559669,  0.03558851,  0.00566923,
#           0.00558462,  0.03219602, -0.0095192 , -0.02308344,
#           0.04466433, -0.02639989]],
#
#        [[ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [-0.00989348,  0.01765114, -0.02019778,  0.00301168,
#           0.02334965, -0.02057335, -0.00069858, -0.04758209,
#          -0.01952232,  0.04292783],
#         [ 0.03549923,  0.00736292,  0.0293092 , -0.0038959 ,
#          -0.00548924,  0.0190313 ,  0.04132498, -0.02958447,
#           0.04034856,  0.00865284],
#         [-0.04580243,  0.04535792,  0.04891628, -0.01987957,
#           0.01732475,  0.03244294, -0.00099039, -0.02901931,
#           0.04306642,  0.0497433 ],
#         [-0.02199103, -0.03822392,  0.01808083, -0.04034377,
#           0.03110459,  0.0361602 ,  0.01580681,  0.03885395,
#           0.00293847,  0.04842247]]], dtype=float32)

# %%
embedded_docs[0]  #first sentence with 4 words
# Out:
# array([   0,    0,    0,    0, 2657, 5609, 4732, 2125], dtype=int32)

# %%
model.predict(np.expand_dims(embedded_docs[0], axis=0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# array([[[ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.02918461,  0.00161979, -0.03210993,  0.04361456,
#          -0.01902115, -0.04142202,  0.02260034,  0.02456447,
#          -0.04772374, -0.0385474 ],
#         [ 0.00888033,  0.03062949, -0.0448764 ,  0.01047868,
#          -0.03260628,  0.01121153,  0.00290543, -0.02765107,
#          -0.04798968,  0.03071565],
#         [ 0.01740136, -0.00744066,  0.03062725, -0.00139483,
#           0.02396477,  0.0080872 ,  0.02169557,  0.02312605,
#           0.03942302,  0.02930372],
#         [ 0.04266275, -0.01209296,  0.03286846,  0.02094408,
#           0.03892087, -0.04899366, -0.00616714,  0.03066054,
#           0.03578006, -0.03786604],
#         [ 0.04649094,  0.01658745, -0.00435399,  0.01235045,
#          -0.02393621,  0.02161782,  0.04900526, -0.02386959,
#           0.02127314,  0.02714082]]], dtype=float32)
